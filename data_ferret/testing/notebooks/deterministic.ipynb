# %%
# Cell A: Simple assignment
x = 10
y = 20

# %%
# Cell B: Computation using x and y
z = x + y
w = x * y

# %%
# Cell C: List operations
numbers = [1, 2, 3, 4, 5]
doubled = [n * 2 for n in numbers]

# %%
# Cell D: Dictionary operations
data = {'a': 1, 'b': 2, 'c': 3}
keys = list(data.keys())
values = list(data.values())

# %%
# Cell E: String operations
message = 'hello world'
upper_message = message.upper()
word_count = len(message.split())

# %%
# Cell F: Combining previous results
total = z + w + sum(doubled)
result = f'{upper_message}: {total}'

# %%
# Cell A: Deterministic setup
import random
n = 10

# %%
# Cell B: Non-deterministic - random number
rand_val = random.random()

# %%
# Cell C: Non-deterministic - random list
rand_list = [random.randint(0, 100) for _ in range(n)]

# %%
# Cell D: Deterministic - uses fixed values
fixed_sum = sum(range(n))
fixed_product = n * 2

# %%
# Cell E: Non-deterministic - random choice
choices = ['apple', 'banana', 'cherry']
picked = random.choice(choices)

# %%
# Cell A: Initialize base values
base = 100
multiplier = 5

# %%
# Cell B: Depends on A
computed = base * multiplier

# %%
# Cell C: Depends on B
doubled = computed * 2

# %%
# Cell D: Depends on A and C
combined = base + doubled

# %%
# Cell E: Independent calculation
independent = 42 * 3

# %%
# Cell F: Depends on D and E
final = combined + independent

# %%
# Cell G: Modify base (would cause staleness in real SDC)
base = 200

# %%
# Cell H: Uses the new base
new_computed = base * multiplier

# %%
x = 1

# %%
y = 10

# %%
print(y)

# %%
y = x + 1

# %%
x = 100

# %%
x = 23

# %%
y = x + 3

# %%
x = 5

# %%
x = 0
# Out:
# ✓ Execute: 17 ms | Code: 1 ms | State: 6 ms (pre=2, post=4) | Check: 6 ms | Writes: x

# %%
print(x)
# Out:
# ⚠️ Contaminated: `x` written by downstream cell <edited>. Right-click → "Run with upstream state" to fix.
# ⚠️ Forward contamination: Cell @L reads orphaned location(s) ['x'].
# These values were written by code that has since been edited.
# Re-run the cell(s) that write to ['x'] to clear contamination.
# 1
# ✓ Execute: 15 ms | Code: 1 ms | State: 6 ms (pre=3, post=4) | Check: 3 ms | Reads: x | Stale: @L

# %%
y = 1
# Out:
# ✓ Execute: 19 ms | Code: 1 ms | State: 9 ms (pre=4, post=5) | Check: 5 ms | Writes: y | Stale: @L

# %%
print(x)

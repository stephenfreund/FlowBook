# %%
# %enable_monotone_updates
# Out:
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'><b>Cell theu</b></div>
# [05:42:27] [[monotone] Enabling monotone updates enforcement]
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'>📊 Global variable tracking enabled</div>
# [05:42:27] [[monotone] Auto-enabling global tracking (required for RBW detection)]
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'>✅ Monotone updates enforcement enabled</div>
# [05:42:27] [[monotone] Checking monotonicity for cell theu...]
# [05:42:27]   [[monotone] Read-before-write vars: set()]
# [05:42:27]   [[monotone] No RBW vars to check, skipping]
# [05:42:27] [0 ms]

# %%
import pandas as pd
import numpy as np
# Out:
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'><b>Cell rrke</b></div>
# [05:42:27] [[monotone] Saving pre-checkpoint for cell rrke...]
# [05:42:27]   [Deep copying user namespace... 4 ms]
# [05:42:27] [4 ms]
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'>⏱️ 0.18s</div>
# [05:42:27] [[monotone] Checking monotonicity for cell rrke...]
# [05:42:27]   [[monotone] Read-before-write vars: set()]
# [05:42:27]   [[monotone] No RBW vars to check, skipping]
# [05:42:27] [0 ms]

# %%
df = pd.DataFrame()
# Out:
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'><b>Cell bhrm</b></div>
# [05:42:27] [[monotone] Saving pre-checkpoint for cell bhrm...]
# [05:42:27]   [Deep copying user namespace... 0 ms]
# [05:42:27] [0 ms]
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'>⏱️ 0.07s</div>
# [05:42:27] [[monotone] Checking monotonicity for cell bhrm...]
# [05:42:27]   [[monotone] Read-before-write vars: set()]
# [05:42:27]   [[monotone] No RBW vars to check, skipping]
# [05:42:27] [0 ms]

# %%
df
# Out:
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'><b>Cell afbcaed7-2460-4078-9c66-ffffd285bba1</b></div>
# [05:42:28] [[monotone] Saving pre-checkpoint for cell afbcaed7-2460-4078-9c66-ffffd285bba1...]
# [05:42:28]   [Deep copying user namespace... 0 ms]
# [05:42:28] [3 ms]
# Empty DataFrame
# Columns: []
# Index: []
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'>⏱️ 0.08s</div>
# [05:42:28] [[monotone] Checking monotonicity for cell afbcaed7-2460-4078-9c66-ffffd285bba1...]
# [05:42:28]   [[monotone] Read-before-write vars: {'df'}]
# [05:42:28]   [[monotone] Computing diff... 0 ms]
# [05:42:28]   [[monotone] Diff result: no differences]
# [05:42:28]   [[monotone] PASSED]
# [05:42:28] [0 ms]

# %%
df["a"] = np.array([1,2,4])
df["b"] = np.array([1,2,4])
# Out:
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'><b>Cell 3753c9a5-a806-497c-8957-53a0d58369de</b></div>
# [05:42:28] [[monotone] Saving pre-checkpoint for cell 3753c9a5-a806-497c-8957-53a0d58369de...]
# [05:42:28]   [Deep copying user namespace... 0 ms]
# [05:42:28] [2 ms]
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'>⏱️ 0.08s</div>
# [05:42:28] [[monotone] Checking monotonicity for cell 3753c9a5-a806-497c-8957-53a0d58369de...]
# [05:42:28]   [[monotone] Read-before-write vars: {'df'}]
# [05:42:28]   [[monotone] Computing diff... 0 ms]
# [05:42:28]   [[monotone] Diff result: no differences]
# [05:42:28]   [[monotone] PASSED]
# [05:42:28] [0 ms]

# %%
df["a"] + 3
# Out:
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'><b>Cell e92ebfad-c4ef-4268-9ec7-336e0a291f08</b></div>
# [05:42:28] [[monotone] Saving pre-checkpoint for cell e92ebfad-c4ef-4268-9ec7-336e0a291f08...]
# [05:42:28]   [Deep copying user namespace... 1 ms]
# [05:42:28] [2 ms]
# 0    4
# 1    5
# 2    7
# Name: a, dtype: int64
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'>⏱️ 0.08s</div>
# [05:42:28] [[monotone] Checking monotonicity for cell e92ebfad-c4ef-4268-9ec7-336e0a291f08...]
# [05:42:28]   [[monotone] Read-before-write vars: {'df'}]
# [05:42:28]   [[monotone] Computing diff... 0 ms]
# [05:42:28]   [[monotone] Diff result: no differences]
# [05:42:28]   [[monotone] PASSED]
# [05:42:28] [0 ms]

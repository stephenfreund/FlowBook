# %%
# %continue_after_violation
# Out:
# <div style='padding-left: 1em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'>info Continue after violation: enabled</div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
import holidays
from sklearn.linear_model import Ridge
# Out:
# <div style='padding-left: 1em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'> Run: 816 ms | Check: 4 ms | Writes: Ridge</div>

# %%
train = pd.read_csv('./train.csv', parse_dates=['date'])
test = pd.read_csv('./test.csv', parse_dates=['date'])
train = train.dropna().reset_index(drop=True)
df = pd.concat([train, test], sort=False).reset_index(drop=True)
df
# Out:
#             id       date  ...             product num_sold
# 0            1 2010-01-01  ...              Kaggle    973.0
# 1            2 2010-01-01  ...        Kaggle Tiers    906.0
# 2            3 2010-01-01  ...            Kerneler    423.0
# 3            4 2010-01-01  ...  Kerneler Dark Mode    491.0
# 4            5 2010-01-01  ...   Holographic Goose    300.0
# ...        ...        ...  ...                 ...      ...
# 319804  328675 2019-12-31  ...   Holographic Goose      NaN
# 319805  328676 2019-12-31  ...              Kaggle      NaN
# 319806  328677 2019-12-31  ...        Kaggle Tiers      NaN
# 319807  328678 2019-12-31  ...            Kerneler      NaN
# 319808  328679 2019-12-31  ...  Kerneler Dark Mode      NaN
#
# [319809 rows x 6 columns]
# <div style='padding-left: 1em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'> Run: 176 ms | Check: 22 ms | Writes: train,test,df</div>

# %%
df['year'] = df['date'].dt.year
# Out:
# <div style='padding-left: 1em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'> Run: 6 ms | Check: 34 ms | Reads: df[date] | Writes: df[year]</div>

# %%
print(df['year'])
# Out:
# 0         2010
# 1         2010
# 2         2010
# 3         2010
# 4         2010
#           ...
# 319804    2019
# 319805    2019
# 319806    2019
# 319807    2019
# 319808    2019
# Name: year, Length: 319809, dtype: int32
# <div style='padding-left: 1em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'> Run: 2 ms | Check: 33 ms | Reads: df[year]</div>

# %%
# Near Holiday
df['near_holiday'] = 0
second = df
second['year'] = 20
# Out:
# ============================================================
# TRUNCATED DIFF DETAILS
# ============================================================
#
# Variable: df
# ----------------------------------------
# {"['year']": {'[0]': {'after': 'np.int64(20)',
#                       'before': 'np.int64(2010)',
#                       'message': "Integer mismatch at df['year'][0]: 2010 vs 20",
#                       'status': 'different'},
#               '[100]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][100]: 2010 vs 20",
#                         'status': 'different'},
#               '[101]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][101]: 2010 vs 20",
#                         'status': 'different'},
#               '[102]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][102]: 2010 vs 20",
#                         'status': 'different'},
#               '[103]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][103]: 2010 vs 20",
#                         'status': 'different'},
#               '[104]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][104]: 2010 vs 20",
#                         'status': 'different'},
#               '[105]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][105]: 2010 vs 20",
#                         'status': 'different'},
#               '[106]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][106]: 2010 vs 20",
#                         'status': 'different'},
#               '[107]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][107]: 2010 vs 20",
#                         'status': 'different'},
#               '[108]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][108]: 2010 vs 20",
#                         'status': 'different'},
#               '[109]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][109]: 2010 vs 20",
#                         'status': 'different'},
#               '[10]': {'after': 'np.int64(20)',
#                        'before': 'np.int64(2010)',
#                        'message': "Integer mismatch at df['year'][10]: 2010 vs 20",
#                        'status': 'different'},
#               '[110]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][110]: 2010 vs 20",
#                         'status': 'different'},
#               '[111]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][111]: 2010 vs 20",
#                         'status': 'different'},
#               '[112]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][112]: 2010 vs 20",
#                         'status': 'different'},
#               '[113]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][113]: 2010 vs 20",
#                         'status': 'different'},
#               '[114]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][114]: 2010 vs 20",
#                         'status': 'different'},
#               '[115]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][115]: 2010 vs 20",
#                         'status': 'different'},
#               '[116]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][116]: 2010 vs 20",
#                         'status': 'different'},
#               '[117]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][117]: 2010 vs 20",
#                         'status': 'different'},
#               '[118]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][118]: 2010 vs 20",
#                         'status': 'different'},
#               '[119]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][119]: 2010 vs 20",
#                         'status': 'different'},
#               '[11]': {'after': 'np.int64(20)',
#                        'before': 'np.int64(2010)',
#                        'message': "Integer mismatch at df['year'][11]: 2010 vs 20",
#                        'status': 'different'},
#               '[120]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][120]: 2010 vs 20",
#                         'status': 'different'},
#               '[121]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][121]: 2010 vs 20",
#                         'status': 'different'},
#               '[122]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][122]: 2010 vs 20",
#                         'status': 'different'},
#               '[123]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][123]: 2010 vs 20",
#                         'status': 'different'},
#               '[124]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][124]: 2010 vs 20",
#                         'status': 'different'},
#               '[125]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][125]: 2010 vs 20",
#                         'status': 'different'},
#               '[126]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][126]: 2010 vs 20",
#                         'status': 'different'},
#               '[127]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][127]: 2010 vs 20",
#                         'status': 'different'},
#               '[128]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][128]: 2010 vs 20",
#                         'status': 'different'},
#               '[129]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][129]: 2010 vs 20",
#                         'status': 'different'},
#               '[12]': {'after': 'np.int64(20)',
#                        'before': 'np.int64(2010)',
#                        'message': "Integer mismatch at df['year'][12]: 2010 vs 20",
#                        'status': 'different'},
#               '[130]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][130]: 2010 vs 20",
#                         'status': 'different'},
#               '[131]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][131]: 2010 vs 20",
#                         'status': 'different'},
#               '[132]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][132]: 2010 vs 20",
#                         'status': 'different'},
#               '[133]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][133]: 2010 vs 20",
#                         'status': 'different'},
#               '[134]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][134]: 2010 vs 20",
#                         'status': 'different'},
#               '[135]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][135]: 2010 vs 20",
#                         'status': 'different'},
#               '[136]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][136]: 2010 vs 20",
#                         'status': 'different'},
#               '[137]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][137]: 2010 vs 20",
#                         'status': 'different'},
#               '[138]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][138]: 2010 vs 20",
#                         'status': 'different'},
#               '[139]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][139]: 2010 vs 20",
#                         'status': 'different'},
#               '[13]': {'after': 'np.int64(20)',
#                        'before': 'np.int64(2010)',
#                        'message': "Integer mismatch at df['year'][13]: 2010 vs 20",
#                        'status': 'different'},
#               '[140]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][140]: 2010 vs 20",
#                         'status': 'different'},
#               '[141]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][141]: 2010 vs 20",
#                         'status': 'different'},
#               '[142]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][142]: 2010 vs 20",
#                         'status': 'different'},
#               '[143]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][143]: 2010 vs 20",
#                         'status': 'different'},
#               '[144]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][144]: 2010 vs 20",
#                         'status': 'different'},
#               '[145]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][145]: 2010 vs 20",
#                         'status': 'different'},
#               '[146]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][146]: 2010 vs 20",
#                         'status': 'different'},
#               '[147]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][147]: 2010 vs 20",
#                         'status': 'different'},
#               '[148]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][148]: 2010 vs 20",
#                         'status': 'different'},
#               '[149]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][149]: 2010 vs 20",
#                         'status': 'different'},
#               '[14]': {'after': 'np.int64(20)',
#                        'before': 'np.int64(2010)',
#                        'message': "Integer mismatch at df['year'][14]: 2010 vs 20",
#                        'status': 'different'},
#               '[150]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][150]: 2010 vs 20",
#                         'status': 'different'},
#               '[151]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][151]: 2010 vs 20",
#                         'status': 'different'},
#               '[152]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][152]: 2010 vs 20",
#                         'status': 'different'},
#               '[153]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][153]: 2010 vs 20",
#                         'status': 'different'},
#               '[154]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][154]: 2010 vs 20",
#                         'status': 'different'},
#               '[155]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][155]: 2010 vs 20",
#                         'status': 'different'},
#               '[156]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][156]: 2010 vs 20",
#                         'status': 'different'},
#               '[157]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][157]: 2010 vs 20",
#                         'status': 'different'},
#               '[158]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][158]: 2010 vs 20",
#                         'status': 'different'},
#               '[159]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][159]: 2010 vs 20",
#                         'status': 'different'},
#               '[15]': {'after': 'np.int64(20)',
#                        'before': 'np.int64(2010)',
#                        'message': "Integer mismatch at df['year'][15]: 2010 vs 20",
#                        'status': 'different'},
#               '[160]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][160]: 2010 vs 20",
#                         'status': 'different'},
#               '[161]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][161]: 2010 vs 20",
#                         'status': 'different'},
#               '[162]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][162]: 2010 vs 20",
#                         'status': 'different'},
#               '[163]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][163]: 2010 vs 20",
#                         'status': 'different'},
#               '[164]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][164]: 2010 vs 20",
#                         'status': 'different'},
#               '[165]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][165]: 2010 vs 20",
#                         'status': 'different'},
#               '[166]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][166]: 2010 vs 20",
#                         'status': 'different'},
#               '[167]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][167]: 2010 vs 20",
#                         'status': 'different'},
#               '[168]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][168]: 2010 vs 20",
#                         'status': 'different'},
#               '[169]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][169]: 2010 vs 20",
#                         'status': 'different'},
#               '[16]': {'after': 'np.int64(20)',
#                        'before': 'np.int64(2010)',
#                        'message': "Integer mismatch at df['year'][16]: 2010 vs 20",
#                        'status': 'different'},
#               '[170]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][170]: 2010 vs 20",
#                         'status': 'different'},
#               '[171]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][171]: 2010 vs 20",
#                         'status': 'different'},
#               '[172]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][172]: 2010 vs 20",
#                         'status': 'different'},
#               '[173]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][173]: 2010 vs 20",
#                         'status': 'different'},
#               '[174]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][174]: 2010 vs 20",
#                         'status': 'different'},
#               '[175]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][175]: 2010 vs 20",
#                         'status': 'different'},
#               '[176]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][176]: 2010 vs 20",
#                         'status': 'different'},
#               '[177]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][177]: 2010 vs 20",
#                         'status': 'different'},
#               '[178]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][178]: 2010 vs 20",
#                         'status': 'different'},
#               '[179]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][179]: 2010 vs 20",
#                         'status': 'different'},
#               '[17]': {'after': 'np.int64(20)',
#                        'before': 'np.int64(2010)',
#                        'message': "Integer mismatch at df['year'][17]: 2010 vs 20",
#                        'status': 'different'},
#               '[180]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][180]: 2010 vs 20",
#                         'status': 'different'},
#               '[181]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][181]: 2010 vs 20",
#                         'status': 'different'},
#               '[182]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][182]: 2010 vs 20",
#                         'status': 'different'},
#               '[183]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][183]: 2010 vs 20",
#                         'status': 'different'},
#               '[184]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][184]: 2010 vs 20",
#                         'status': 'different'},
#               '[185]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][185]: 2010 vs 20",
#                         'status': 'different'},
#               '[186]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][186]: 2010 vs 20",
#                         'status': 'different'},
#               '[187]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][187]: 2010 vs 20",
#                         'status': 'different'},
#               '[188]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][188]: 2010 vs 20",
#                         'status': 'different'},
#               '[189]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][189]: 2010 vs 20",
#                         'status': 'different'},
#               '[18]': {'after': 'np.int64(20)',
#                        'before': 'np.int64(2010)',
#                        'message': "Integer mismatch at df['year'][18]: 2010 vs 20",
#                        'status': 'different'},
#               '[190]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][190]: 2010 vs 20",
#                         'status': 'different'},
#               '[191]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][191]: 2010 vs 20",
#                         'status': 'different'},
#               '[192]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][192]: 2010 vs 20",
#                         'status': 'different'},
#               '[193]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][193]: 2010 vs 20",
#                         'status': 'different'},
#               '[194]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][194]: 2010 vs 20",
#                         'status': 'different'},
#               '[195]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][195]: 2010 vs 20",
#                         'status': 'different'},
#               '[196]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][196]: 2010 vs 20",
#                         'status': 'different'},
#               '[197]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][197]: 2010 vs 20",
#                         'status': 'different'},
#               '[198]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][198]: 2010 vs 20",
#                         'status': 'different'},
#               '[199]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][199]: 2010 vs 20",
#                         'status': 'different'},
#               '[19]': {'after': 'np.int64(20)',
#                        'before': 'np.int64(2010)',
#                        'message': "Integer mismatch at df['year'][19]: 2010 vs 20",
#                        'status': 'different'},
#               '[1]': {'after': 'np.int64(20)',
#                       'before': 'np.int64(2010)',
#                       'message': "Integer mismatch at df['year'][1]: 2010 vs 20",
#                       'status': 'different'},
#               '[200]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][200]: 2010 vs 20",
#                         'status': 'different'},
#               '[201]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][201]: 2010 vs 20",
#                         'status': 'different'},
#               '[202]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][202]: 2010 vs 20",
#                         'status': 'different'},
#               '[203]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][203]: 2010 vs 20",
#                         'status': 'different'},
#               '[204]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][204]: 2010 vs 20",
#                         'status': 'different'},
#               '[205]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][205]: 2010 vs 20",
#                         'status': 'different'},
#               '[206]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][206]: 2010 vs 20",
#                         'status': 'different'},
#               '[207]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][207]: 2010 vs 20",
#                         'status': 'different'},
#               '[208]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][208]: 2010 vs 20",
#                         'status': 'different'},
#               '[209]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][209]: 2010 vs 20",
#                         'status': 'different'},
#               '[20]': {'after': 'np.int64(20)',
#                        'before': 'np.int64(2010)',
#                        'message': "Integer mismatch at df['year'][20]: 2010 vs 20",
#                        'status': 'different'},
#               '[210]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][210]: 2010 vs 20",
#                         'status': 'different'},
#               '[211]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][211]: 2010 vs 20",
#                         'status': 'different'},
#               '[212]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][212]: 2010 vs 20",
#                         'status': 'different'},
#               '[213]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][213]: 2010 vs 20",
#                         'status': 'different'},
#               '[214]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][214]: 2010 vs 20",
#                         'status': 'different'},
#               '[215]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][215]: 2010 vs 20",
#                         'status': 'different'},
#               '[216]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][216]: 2010 vs 20",
#                         'status': 'different'},
#               '[217]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][217]: 2010 vs 20",
#                         'status': 'different'},
#               '[218]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][218]: 2010 vs 20",
#                         'status': 'different'},
#               '[219]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][219]: 2010 vs 20",
#                         'status': 'different'},
#               '[21]': {'after': 'np.int64(20)',
#                        'before': 'np.int64(2010)',
#                        'message': "Integer mismatch at df['year'][21]: 2010 vs 20",
#                        'status': 'different'},
#               '[220]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][220]: 2010 vs 20",
#                         'status': 'different'},
#               '[221]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][221]: 2010 vs 20",
#                         'status': 'different'},
#               '[222]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][222]: 2010 vs 20",
#                         'status': 'different'},
#               '[223]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][223]: 2010 vs 20",
#                         'status': 'different'},
#               '[224]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][224]: 2010 vs 20",
#                         'status': 'different'},
#               '[225]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][225]: 2010 vs 20",
#                         'status': 'different'},
#               '[226]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][226]: 2010 vs 20",
#                         'status': 'different'},
#               '[227]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][227]: 2010 vs 20",
#                         'status': 'different'},
#               '[228]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][228]: 2010 vs 20",
#                         'status': 'different'},
#               '[229]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][229]: 2010 vs 20",
#                         'status': 'different'},
#               '[22]': {'after': 'np.int64(20)',
#                        'before': 'np.int64(2010)',
#                        'message': "Integer mismatch at df['year'][22]: 2010 vs 20",
#                        'status': 'different'},
#               '[230]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][230]: 2010 vs 20",
#                         'status': 'different'},
#               '[231]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][231]: 2010 vs 20",
#                         'status': 'different'},
#               '[232]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][232]: 2010 vs 20",
#                         'status': 'different'},
#               '[233]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][233]: 2010 vs 20",
#                         'status': 'different'},
#               '[234]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][234]: 2010 vs 20",
#                         'status': 'different'},
#               '[235]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][235]: 2010 vs 20",
#                         'status': 'different'},
#               '[236]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][236]: 2010 vs 20",
#                         'status': 'different'},
#               '[237]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][237]: 2010 vs 20",
#                         'status': 'different'},
#               '[238]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][238]: 2010 vs 20",
#                         'status': 'different'},
#               '[239]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][239]: 2010 vs 20",
#                         'status': 'different'},
#               '[23]': {'after': 'np.int64(20)',
#                        'before': 'np.int64(2010)',
#                        'message': "Integer mismatch at df['year'][23]: 2010 vs 20",
#                        'status': 'different'},
#               '[240]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][240]: 2010 vs 20",
#                         'status': 'different'},
#               '[241]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][241]: 2010 vs 20",
#                         'status': 'different'},
#               '[242]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][242]: 2010 vs 20",
#                         'status': 'different'},
#               '[243]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][243]: 2010 vs 20",
#                         'status': 'different'},
#               '[244]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][244]: 2010 vs 20",
#                         'status': 'different'},
#               '[245]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][245]: 2010 vs 20",
#                         'status': 'different'},
#               '[246]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][246]: 2010 vs 20",
#                         'status': 'different'},
#               '[247]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][247]: 2010 vs 20",
#                         'status': 'different'},
#               '[248]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][248]: 2010 vs 20",
#                         'status': 'different'},
#               '[249]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][249]: 2010 vs 20",
#                         'status': 'different'},
#               '[24]': {'after': 'np.int64(20)',
#                        'before': 'np.int64(2010)',
#                        'message': "Integer mismatch at df['year'][24]: 2010 vs 20",
#                        'status': 'different'},
#               '[250]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][250]: 2010 vs 20",
#                         'status': 'different'},
#               '[251]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][251]: 2010 vs 20",
#                         'status': 'different'},
#               '[252]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][252]: 2010 vs 20",
#                         'status': 'different'},
#               '[253]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][253]: 2010 vs 20",
#                         'status': 'different'},
#               '[254]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][254]: 2010 vs 20",
#                         'status': 'different'},
#               '[255]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][255]: 2010 vs 20",
#                         'status': 'different'},
#               '[256]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][256]: 2010 vs 20",
#                         'status': 'different'},
#               '[257]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][257]: 2010 vs 20",
#                         'status': 'different'},
#               '[258]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][258]: 2010 vs 20",
#                         'status': 'different'},
#               '[259]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][259]: 2010 vs 20",
#                         'status': 'different'},
#               '[25]': {'after': 'np.int64(20)',
#                        'before': 'np.int64(2010)',
#                        'message': "Integer mismatch at df['year'][25]: 2010 vs 20",
#                        'status': 'different'},
#               '[260]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][260]: 2010 vs 20",
#                         'status': 'different'},
#               '[261]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][261]: 2010 vs 20",
#                         'status': 'different'},
#               '[262]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][262]: 2010 vs 20",
#                         'status': 'different'},
#               '[263]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][263]: 2010 vs 20",
#                         'status': 'different'},
#               '[264]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][264]: 2010 vs 20",
#                         'status': 'different'},
#               '[265]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][265]: 2010 vs 20",
#                         'status': 'different'},
#               '[266]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][266]: 2010 vs 20",
#                         'status': 'different'},
#               '[267]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][267]: 2010 vs 20",
#                         'status': 'different'},
#               '[268]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][268]: 2010 vs 20",
#                         'status': 'different'},
#               '[269]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][269]: 2010 vs 20",
#                         'status': 'different'},
#               '[26]': {'after': 'np.int64(20)',
#                        'before': 'np.int64(2010)',
#                        'message': "Integer mismatch at df['year'][26]: 2010 vs 20",
#                        'status': 'different'},
#               '[270]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][270]: 2010 vs 20",
#                         'status': 'different'},
#               '[271]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][271]: 2010 vs 20",
#                         'status': 'different'},
#               '[272]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][272]: 2010 vs 20",
#                         'status': 'different'},
#               '[273]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][273]: 2010 vs 20",
#                         'status': 'different'},
#               '[274]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][274]: 2010 vs 20",
#                         'status': 'different'},
#               '[275]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][275]: 2010 vs 20",
#                         'status': 'different'},
#               '[276]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][276]: 2010 vs 20",
#                         'status': 'different'},
#               '[277]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][277]: 2010 vs 20",
#                         'status': 'different'},
#               '[278]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][278]: 2010 vs 20",
#                         'status': 'different'},
#               '[279]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][279]: 2010 vs 20",
#                         'status': 'different'},
#               '[27]': {'after': 'np.int64(20)',
#                        'before': 'np.int64(2010)',
#                        'message': "Integer mismatch at df['year'][27]: 2010 vs 20",
#                        'status': 'different'},
#               '[280]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][280]: 2010 vs 20",
#                         'status': 'different'},
#               '[281]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][281]: 2010 vs 20",
#                         'status': 'different'},
#               '[282]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][282]: 2010 vs 20",
#                         'status': 'different'},
#               '[283]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][283]: 2010 vs 20",
# ...
#                         'message': "Integer mismatch at df['year'][941]: 2010 vs 20",
#                         'status': 'different'},
#               '[942]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][942]: 2010 vs 20",
#                         'status': 'different'},
#               '[943]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][943]: 2010 vs 20",
#                         'status': 'different'},
#               '[944]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][944]: 2010 vs 20",
#                         'status': 'different'},
#               '[945]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][945]: 2010 vs 20",
#                         'status': 'different'},
#               '[946]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][946]: 2010 vs 20",
#                         'status': 'different'},
#               '[947]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][947]: 2010 vs 20",
#                         'status': 'different'},
#               '[948]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][948]: 2010 vs 20",
#                         'status': 'different'},
#               '[949]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][949]: 2010 vs 20",
#                         'status': 'different'},
#               '[94]': {'after': 'np.int64(20)',
#                        'before': 'np.int64(2010)',
#                        'message': "Integer mismatch at df['year'][94]: 2010 vs 20",
#                        'status': 'different'},
#               '[950]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][950]: 2010 vs 20",
#                         'status': 'different'},
#               '[951]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][951]: 2010 vs 20",
#                         'status': 'different'},
#               '[952]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][952]: 2010 vs 20",
#                         'status': 'different'},
#               '[953]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][953]: 2010 vs 20",
#                         'status': 'different'},
#               '[954]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][954]: 2010 vs 20",
#                         'status': 'different'},
#               '[955]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][955]: 2010 vs 20",
#                         'status': 'different'},
#               '[956]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][956]: 2010 vs 20",
#                         'status': 'different'},
#               '[957]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][957]: 2010 vs 20",
#                         'status': 'different'},
#               '[958]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][958]: 2010 vs 20",
#                         'status': 'different'},
#               '[959]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][959]: 2010 vs 20",
#                         'status': 'different'},
#               '[95]': {'after': 'np.int64(20)',
#                        'before': 'np.int64(2010)',
#                        'message': "Integer mismatch at df['year'][95]: 2010 vs 20",
#                        'status': 'different'},
#               '[960]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][960]: 2010 vs 20",
#                         'status': 'different'},
#               '[961]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][961]: 2010 vs 20",
#                         'status': 'different'},
#               '[962]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][962]: 2010 vs 20",
#                         'status': 'different'},
#               '[963]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][963]: 2010 vs 20",
#                         'status': 'different'},
#               '[964]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][964]: 2010 vs 20",
#                         'status': 'different'},
#               '[965]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][965]: 2010 vs 20",
#                         'status': 'different'},
#               '[966]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][966]: 2010 vs 20",
#                         'status': 'different'},
#               '[967]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][967]: 2010 vs 20",
#                         'status': 'different'},
#               '[968]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][968]: 2010 vs 20",
#                         'status': 'different'},
#               '[969]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][969]: 2010 vs 20",
#                         'status': 'different'},
#               '[96]': {'after': 'np.int64(20)',
#                        'before': 'np.int64(2010)',
#                        'message': "Integer mismatch at df['year'][96]: 2010 vs 20",
#                        'status': 'different'},
#               '[970]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][970]: 2010 vs 20",
#                         'status': 'different'},
#               '[971]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][971]: 2010 vs 20",
#                         'status': 'different'},
#               '[972]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][972]: 2010 vs 20",
#                         'status': 'different'},
#               '[973]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][973]: 2010 vs 20",
#                         'status': 'different'},
#               '[974]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][974]: 2010 vs 20",
#                         'status': 'different'},
#               '[975]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][975]: 2010 vs 20",
#                         'status': 'different'},
#               '[976]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][976]: 2010 vs 20",
#                         'status': 'different'},
#               '[977]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][977]: 2010 vs 20",
#                         'status': 'different'},
#               '[978]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][978]: 2010 vs 20",
#                         'status': 'different'},
#               '[979]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][979]: 2010 vs 20",
#                         'status': 'different'},
#               '[97]': {'after': 'np.int64(20)',
#                        'before': 'np.int64(2010)',
#                        'message': "Integer mismatch at df['year'][97]: 2010 vs 20",
#                        'status': 'different'},
#               '[980]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][980]: 2010 vs 20",
#                         'status': 'different'},
#               '[981]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][981]: 2010 vs 20",
#                         'status': 'different'},
#               '[982]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][982]: 2010 vs 20",
#                         'status': 'different'},
#               '[983]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][983]: 2010 vs 20",
#                         'status': 'different'},
#               '[984]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][984]: 2010 vs 20",
#                         'status': 'different'},
#               '[985]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][985]: 2010 vs 20",
#                         'status': 'different'},
#               '[986]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][986]: 2010 vs 20",
#                         'status': 'different'},
#               '[987]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][987]: 2010 vs 20",
#                         'status': 'different'},
#               '[988]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][988]: 2010 vs 20",
#                         'status': 'different'},
#               '[989]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][989]: 2010 vs 20",
#                         'status': 'different'},
#               '[98]': {'after': 'np.int64(20)',
#                        'before': 'np.int64(2010)',
#                        'message': "Integer mismatch at df['year'][98]: 2010 vs 20",
#                        'status': 'different'},
#               '[990]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][990]: 2010 vs 20",
#                         'status': 'different'},
#               '[991]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][991]: 2010 vs 20",
#                         'status': 'different'},
#               '[992]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][992]: 2010 vs 20",
#                         'status': 'different'},
#               '[993]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][993]: 2010 vs 20",
#                         'status': 'different'},
#               '[994]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][994]: 2010 vs 20",
#                         'status': 'different'},
#               '[995]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][995]: 2010 vs 20",
#                         'status': 'different'},
#               '[996]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][996]: 2010 vs 20",
#                         'status': 'different'},
#               '[997]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][997]: 2010 vs 20",
#                         'status': 'different'},
#               '[998]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][998]: 2010 vs 20",
#                         'status': 'different'},
#               '[999]': {'after': 'np.int64(20)',
#                         'before': 'np.int64(2010)',
#                         'message': "Integer mismatch at df['year'][999]: 2010 vs 20",
#                         'status': 'different'},
#               '[99]': {'after': 'np.int64(20)',
#                        'before': 'np.int64(2010)',
#                        'message': "Integer mismatch at df['year'][99]: 2010 vs 20",
#                        'status': 'different'},
#               '[9]': {'after': 'np.int64(20)',
#                       'before': 'np.int64(2010)',
#                       'message': "Integer mismatch at df['year'][9]: 2010 vs 20",
#                       'status': 'different'},
#               '_truncated': {'message': 'Truncated after 1000 differences (max_diffs_per_container=1000)',
#                              'status': 'different'}},
#  '_truncated': {'message': 'Truncated after 1000 differences (max_diffs_per_structure=100)', 'status': 'different'}}
#
# ============================================================
# ⚠️ SDC Violation (continuing): Cell @F modified ['df'] which cell @F reads.
# <div style='padding-left: 1em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'> Run: 2 ms | Check: 311 ms | Reads: df | Writes: second,df[near_holiday,year]</div>

# %%
z = [year for year in df['year'].unique() for country in df['country'].unique()]
# Out:
# <div style='padding-left: 1em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'> Run: 12 ms | Check: 115 ms | Reads: df[country,year] | Writes: z | Stale: @E,@F</div>

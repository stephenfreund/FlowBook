# %%
import pandas as pd
# %structural_tracking enforce
# Out:
# <div style='padding-left: 1em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'>✅ Structural tracking mode set to: enforce</div>
# <div style='padding-left: 1em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'>✓ Run: 7 ms | State: 4 ms | Check: 0 ms | Reads: open</div>

# %%
df = pd.DataFrame({'x': [1, 2, 3]})
# Out:
# <div style='padding-left: 1em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'>✓ Run: 2 ms | State: 2 ms | Check: 0 ms | Writes: df</div>

# %%
# Read the shape
print(f"Shape: {df.shape}")
# Out:
# Shape: (3, 1)
# <div style='padding-left: 1em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'>✓ Run: 1 ms | State: 2 ms | Check: 0 ms | Reads: df</div>

# %%
# Add a row - should violate SDC because earlier cell read shape
df.loc[len(df)] = [4]
# Out:
# Sequential Dataflow Consistency Violation
#
# Cell @D modified variables that cell @C (earlier in notebook) reads.
#
# Affected variables: ['df']
#
# This breaks reproducibility. The earlier cell's behavior depends on this cell having run first.

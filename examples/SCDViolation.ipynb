# %%
x = 13
# Out:
# ✓ Run: 1 ms | State: 3 ms | Check: 3 ms | Writes: x

# %%
y = x + 1
# Out:
# ✓ Run: 1 ms | State: 4 ms | Check: 4 ms | Reads: x | Writes: y

# %%
print(y)
# Out:
# 14
# ✓ Run: 1 ms | State: 4 ms | Check: 2 ms | Reads: y

# %%
x = 20
# Out:
# ❌ Reproducibility Violation: Backward Structural Mutation
#
# Cell @D modified x which Cell @B (earlier) reads.
#
# Why blocked: Cell @B depends on Cell @D having run first, breaking top-to-bottom reproducibility.
#
# Fix: Move the modification before the read, or avoid reading structural attributes that will change.

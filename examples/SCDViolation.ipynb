# %%
x = 10
# Out:
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'>check 0.00s | W:x</div>

# %%
y = x + 1
# Out:
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'>check 0.00s | R:x | W:y</div>

# %%
y = 18
# Out:
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'>check 0.00s | W:y | stale:0a66430f-7cdc-4885-b89b-93ad8383614b</div>

# %%
print(y)
# Out:
# 11
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'>check 0.00s | R:y</div>

# %%
x = 11
# Out:
# Sequential Dataflow Consistency Violation
#
# Cell @E modified variables that cell @B (earlier in notebook) reads.
#
# Affected variables: ['x']
#
# This breaks reproducibility. The earlier cell's behavior depends on this cell having run first.

# %%
z = 20

# %%
print(y)
# Out:
# 18
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'>check 0.00s | R:y | stale:0a66430f-7cdc-4885-b89b-93ad8383614b</div>

# %%
y = y + 1
# Out:
# Sequential Dataflow Consistency Violation
#
# Cell @H modified variables that cell @D (earlier in notebook) reads.
#
# Affected variables: ['y']
#
# This breaks reproducibility. The earlier cell's behavior depends on this cell having run first.

# %%
'y' in locals()
# Out:
# True
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'>check 0.00s | stale:0a66430f-7cdc-4885-b89b-93ad8383614b</div>

# %%
y
# Out:
# 18
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'>check 0.00s | R:y | stale:0a66430f-7cdc-4885-b89b-93ad8383614b</div>

# %%
x = 12
# Out:
# <div style='padding-left: 1em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'> Run: 1 ms | Check: 9 ms | Writes: x | Stale: @B</div>

# %%
y = x + 1
# Out:
# <div style='padding-left: 1em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'> Run: 1 ms | Check: 6 ms | Reads: x | Writes: y | Stale: @C</div>

# %%
print(y)
# Out:
# 13
# <div style='padding-left: 1em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'> Run: 2 ms | Check: 5 ms | Reads: y</div>

# %%
x = 20
# Out:
# Sequential Dataflow Consistency Violation
#
# Cell @D modified variables that cell @B (earlier in notebook) reads.
#
# Affected variables: ['x']
#
# This breaks reproducibility. The earlier cell's behavior depends on this cell having run first.

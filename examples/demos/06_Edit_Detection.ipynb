# %% [markdown]
# # Edit Detection
#
# Run A → B. Then edit A (don't run it) and wait 1 second.
#
# **Expected:** Both A and B turn stale — A's code changed, and B depends on A.

# %%
rate = 0.05
# Out:
# ⚠️ Source code was edited

# %%
interest = 1000 * rate
print(f"Interest: ${interest:.2f}")
# Out:
# Interest: $50.00
# ✓ Execute: 6 ms | Code: 1 ms | State: 2 ms | Check: 2 ms | Reads: rate | Writes: interest

# %% [markdown]
# # DataFrame Column Independence
#
# Run A → B → C in order.
#
# **Expected:** C is accepted — it modifies `score` while B only read `age`. Different columns, no conflict.

# %%
import pandas as pd
df = pd.DataFrame({
    'name': ['Alice', 'Bob'],
    'age': [30, 25],
    'score': [85, 92]
})

# %%
avg_age = df['age'].mean()
print(f"Average age: {avg_age}")
# Out:
# Average age: 27.5
# ✓ Execute: 19 ms | Code: 3 ms | State: 6 ms | Check: 5 ms | Reads: age | Writes: avg_age

# %%
df['adjusted_age'] = df['age'] * 1.1  # OK: different column

# %%
df.shape
# Out:
# (2, 4)
# ✓ Execute: 21 ms | Code: 7 ms | State: 4 ms | Check: 7 ms | Reads: columns,index,shape

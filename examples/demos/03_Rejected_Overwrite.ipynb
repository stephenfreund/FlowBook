# %% [markdown]
# # Rejected Overwrite
#
# Run A → B → C in order.
#
# **Expected:** C is rejected — it tries to overwrite `df` which B already read. Namespace is rolled back.

# %%
import pandas as pd
df = pd.DataFrame({'x': [1, 2, 3], 'y': [4, 5, 6]})

# %%
total = df['x'].sum()
print(f"Sum of x: {total}")

# %%
# This will be REJECTED
df = pd.DataFrame({'x': [100, 200, 300]})

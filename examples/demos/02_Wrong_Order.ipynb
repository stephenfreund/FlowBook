# %% [markdown]
# # Running Cells Out of Order
#
# Run C first, then B.
#
# **Expected:** B runs but is marked stale — it read `x` from C, but C is below B in the notebook. Running top-to-bottom would fail.

# %%
# A: the "correct" source
x = 10

# %%
y = x * 2
print(f"y = {y}")
# Out:
# y = 20

# %%
#x = 999

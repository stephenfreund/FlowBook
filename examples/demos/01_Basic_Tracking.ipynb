# %% [markdown]
# # Basic Dependency Tracking
#
# Run A → B → C. Then change A and re-run it.
#
# **Expected:** B and C turn stale (amber) because they depend on A's output.

# %%
price = 100

# %%
tax = price * 0.08
print(f"Tax: ${tax:.2f}")
# Out:
# Tax: $8.00
# ✓ Execute: 10 ms | Code: 1 ms | State: 3 ms | Check: 4 ms | Reads: price | Writes: tax

# %%
total = price + tax
print(f"Total: ${total:.2f}")
# Out:
# Total: $108.00
# ✓ Execute: 11 ms | Code: 1 ms | State: 3 ms | Check: 3 ms | Reads: tax,price | Writes: total

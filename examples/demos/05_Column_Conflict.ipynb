# %% [markdown]
# # DataFrame Column Conflict
#
# Run A → B → C in order.
#
# **Expected:** C is rejected — it reads and writes `age`, same column B read.

# %%
import pandas as pd
df = pd.DataFrame({
    'name': ['Alice', 'Bob'],
    'age': [30, 25]
})

# %%
avg_age = df['age'].mean()
print(f"Average age: {avg_age}")

# %%
# REJECTED: reads age (for +1) then writes age, but B already read age
df['age'] = df['age'] + 1

# %%
df['age'].hist()

# %%
# %enable_global_tracking
# Out:
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'><b>Cell theu</b></div>
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'>📊 Global variable tracking enabled</div>

# %%
# %enable_scalene
# Out:
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'><b>Cell wodq</b></div>
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'>🔍 Scalene profiling enabled</div>

# %%
import math
import random
import time
import numpy as np
# Out:
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'><b>Cell rrke</b></div>
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'>⏱️ 0.06s</div>

# %%
N, d = 2000, 20
pts = np.random.random((N, d))
# Out:
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'><b>Cell bhrm</b></div>
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'>⏱️ 0.05s</div>

# %%
def pairwise_distances(points):
    """
    Given points as a list of tuples (x1,…,xd),
    return an N×N matrix of Euclidean distances.
    """
    N = len(points)
    # initialize an N×N list of zeros
    D = [[0.0]*N for _ in range(N)]
    for i in range(N):
        for j in range(i+1, N):
            # compute distance
            s = 0.0
            for xi, xj in zip(points[i], points[j]):
                diff = xi - xj
                s += diff*diff
            dist = math.sqrt(s)
            D[i][j] = dist
            D[j][i] = dist
    return D
# Out:
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'><b>Cell srqk</b></div>
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'>⏱️ 0.05s</div>

# %%
_start = time.time()
dists = pairwise_distances(pts)
_end = time.time()
_diff = _end - _start
print("Time = ", _diff, "sec")
# Out:
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'><b>Cell usak</b></div>
# Time =  6.321958065032959 sec
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'><details style='display: inline-block; text-align: left;'><summary>🔍 6.99s</summary>
#
# <pre style='margin: 0;'><code>                                                                                                                                                                                                                 Cell srqk: % of time = 100.00% (6.323s) out of 6.323s.
#         ╷        ╷       ╷       ╷
#         │Time    │–––––– │–––––– │
#   Line  │Python  │native │system │Cell srqk
# ╺━━━━━━━┿━━━━━━━━┿━━━━━━━┿━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸
#       1 │        │       │       │def pairwise_distances(points):
#       2 │        │       │       │    """
#       3 │        │       │       │    Given points as a list of tuples (x1,…,xd),
#       4 │        │       │       │    return an N×N matrix of Euclidean distances.
#       5 │        │       │       │    """
#       6 │        │       │       │    N = len(points)
#       7 │        │       │       │    # initialize an N×N list of zeros
#       8 │        │       │       │    D = [[0.0]*N for _ in range(N)]
#       9 │        │       │       │    for i in range(N):
#      10 │        │       │       │        for j in range(i+1, N):
#      11 │        │       │       │            # compute distance
#      12 │        │       │       │            s = 0.0
#      13 │    6%  │    1% │       │            for xi, xj in zip(points[i], points[j]):
#      14 │        │       │       │                diff = xi - xj
#      15 │   65%  │   14% │       │                s += diff*diff
#      16 │   10%  │    2% │       │            dist = math.sqrt(s)
#      17 │        │       │       │            D[i][j] = dist
#      18 │        │       │       │            D[j][i] = dist
#      19 │        │       │       │    return D
#         │        │       │       │
# ╶───────┼────────┼───────┼───────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╴
#         │        │       │       │function summary for Cell srqk
#       1 │   82%  │   17% │       │pairwise_distances
#         ╵        ╵       ╵       ╵
# </code></pre>
#
# </details></div>

# %%
print(dists[0])
# Out:
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'><b>Cell eumk</b></div>
# [0.0, 1.6315739190841667, 1.9301194282342022, 2.1668290340074914, 2.0387196141053257, 2.119909785607771, 1.3461364750963691, 1.6391339979418635, 2.0101083635418475, 1.8560908240527585, 2.266488777936601, 1.7479801481873596, 1.7022517398629262, 1.853610705779737, 2.150832401388091, 1.7675484662180283, 2.1554836321253723, 1.8917458484973178, 2.05204487761754, 1.8896215606974407, 1.290576045917748, 1.9094155622016815, 1.574727042376622, 2.154787919775088, 1.9166971458111575, 2.084444104556141, 1.650203780444292, 2.0032498936515895, 2.155489554647487, 2.4249376695810705, 1.3425313382390516, 2.043877604116249, 1.9502286397245867, 1.7032796392309737, 1.4719188639570493, 2.1862074307925536, 1.962217971425345, 1.789523522314759, 1.9396597703875427
# %%
# %enable_global_tracking
# Out:
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'><b>Cell theu</b></div>
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'>📊 Global variable tracking enabled</div>

# %%
# %enable_scalene
# Out:
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'><b>Cell 278a27d2-1c51-48f7-a9e1-134923d64e74</b></div>
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'>🔍 Scalene profiling enabled</div>

# %%
import math
import random
import time
import numpy as np
# Out:
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'><b>Cell rrke</b></div>
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'>⏱️ 0.14s</div>

# %%
N, d = 2000, 20
pts = np.random.random((N, d))
# Out:
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'><b>Cell bhrm</b></div>
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'>⏱️ 0.06s</div>

# %%
def pairwise_distances(points):
    """
    Given points as a list of tuples (x1,…,xd),
    return an N×N matrix of Euclidean distances.
    """
    N = len(points)
    # initialize an N×N list of zeros
    D = [[0.0]*N for _ in range(N)]
    for i in range(N):
        for j in range(i+1, N):
            # compute distance
            s = 0.0
            for xi, xj in zip(points[i], points[j]):
                diff = xi - xj
                s += diff*diff
            dist = math.sqrt(s)
            D[i][j] = dist
            D[j][i] = dist
    return D
# Out:
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'><b>Cell srqk</b></div>
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'>⏱️ 0.06s</div>

# %%
_start = time.time()
dists = pairwise_distances(pts)
_end = time.time()
_diff = _end - _start
print("Time = ", _diff, "sec")
# Out:
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'><b>Cell usak</b></div>
# Time =  7.154988050460815 sec
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'><details style='display: inline-block; text-align: left;'><summary>🔍 7.86s</summary>
#
# <pre style='margin: 0;'><code>                                                                                                                                                                                                                  /Users/freund/other/DataFerret/data_ferret/kernel/tracking.py: % of time =  16.92% (1.216s) out of 7.187s.
#         ╷        ╷       ╷       ╷
#         │Time    │–––––– │–––––– │
#   Line  │Python  │native │system │/Users/freund/other/DataFerret/data_ferret/kernel/tracking.py
# ╺━━━━━━━┿━━━━━━━━┿━━━━━━━┿━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸
#       1 │        │       │       │"""
#       2 │        │       │       │TrackingDict is a dictionary that tracks reads-before-write, new_vars, and writes.
#       3 │        │       │       │
#       4 │        │       │       │This implementation uses single storage (the parent dict) to avoid synchronization
#       5 │        │       │       │issues that occur with dual storage when IPython's internal methods bypass our
#       6 │        │       │       │overridden methods.
#       7 │        │       │       │"""
#       8 │        │       │       │
#       9 │        │       │       │
#      10 │        │       │       │class TrackingDict(dict):
#      11 │        │       │       │    """A dict subclass that tracks variable access patterns during cell execution."""
#      12 │        │       │       │
#      13 │        │       │       │    def __init__(self, initial_ns=None):
#      14 │        │       │       │        super().__init__()
#      15 │        │       │       │        if initial_ns is not None:
#      16 │        │       │       │            # Copy all contents from the existing namespace
#      17 │        │       │       │            self.update(initial_ns)
#      18 │        │       │       │        self._initial_keys = set(self.keys())
#      19 │        │       │       │        self.reset_tracking()
#      20 │        │       │       │
#      21 │        │       │       │    def reset_tracking(self):
#      22 │        │       │       │        """Reset tracking state for a new cell execution."""
#      23 │        │       │       │        self._reads_before_writes = set()
#      24 │        │       │       │        self._writes = set()
#      25 │        │       │       │        self._new_vars = set()
#      26 │        │       │       │
#      27 │        │       │       │    @property
#      28 │        │       │       │    def reads_before_writes(self):
#      29 │        │       │       │        return self._reads_before_writes
#      30 │        │       │       │
#      31 │        │       │       │    @property
#      32 │        │       │       │    def writes(self):
#      33 │        │       │       │        return self._writes
#      34 │        │       │       │
#      35 │        │       │       │    @property
#      36 │        │       │       │    def new_vars(self):
#      37 │        │       │       │        return self._new_vars
#      38 │        │       │       │
#      39 │   11%  │    2% │       │    def __getitem__(self, key):
#      40 │        │       │       │        # Special handling for __builtins__
#      41 │        │       │       │        if key == '__builtins__':
#      42 │        │       │       │            try:
#      43 │        │       │       │                return super().__getitem__(key)
#      44 │        │       │       │            except KeyError:
#      45 │        │       │       │                import builtins
#      46 │        │       │       │                return builtins.__dict__
#      47 │        │       │       │
#      48 │        │       │       │        val = super().__getitem__(key)
#      49 │        │       │       │        # Track reads of non-private variables that haven't been written yet
#      50 │        │       │       │        if not key.startswith('_') and key not in self._writes:
#      51 │    2%  │       │       │            self._reads_before_writes.add(key)
#      52 │        │       │       │        return val
#      53 │        │       │       │
#      54 │        │       │       │    def __setitem__(self, key, value):
#      55 │        │       │       │        # Track writes of non-private variables
#      56 │        │       │       │        if not key.startswith('_') and key not in self._writes:
#      57 │        │       │       │            self._writes.add(key)
#      58 │        │       │       │            if key not in self._initial_keys:
#      59 │        │       │       │                self._new_vars.add(key)
#      60 │        │       │       │        super().__setitem__(key, value)
#      61 │        │       │       │
#      62 │        │       │       │    def __delitem__(self, key):
#      63 │        │       │       │        super().__delitem__(key)
#      64 │        │       │       │
#      65 │        │       │       │
#      66 │        │       │       │from IPython import get_ipython
#      67 │        │       │       │
#      68 │        │       │       │
#      69 │        │       │       │def pre_run_cell(info):
#      70 │        │       │       │    ip = get_ipython()
#      71 │        │       │       │    # before each cell, just clear out last cell’s logs
#      72 │        │       │       │    ip.user_ns.reset_tracking()
#      73 │        │       │       │
#      74 │        │       │       │
#      75 │        │       │       │def post_run_cell(result):
#      76 │        │       │       │    ip = get_ipython()
#      77 │        │       │       │    # after each cell you can inspect:
#      78 │        │       │       │    print("reads-before-writes:", ip.user_ns.reads_before_writes)
#      79 │        │       │       │    print("writes:", ip.user_ns.writes)
#      80 │        │       │       │    print("new_vars:", ip.user_ns.new_vars)
#      81 │        │       │       │
#      82 │        │       │       │
#      83 │        │       │       │def load_ipython_extension(ipython):
#      84 │        │       │       │    """Load the tracking extension into IPython."""
#      85 │        │       │       │    ipython.user_ns = TrackingDict(ipython.user_ns)
#      86 │        │       │       │    ipython.events.register("pre_run_cell", pre_run_cell)
#      87 │        │       │       │    ipython.events.register("post_run_cell", post_run_cell)
#      88 │        │       │       │    print("✅ tracking_ns loaded: now tracking variable accesses.")
#      89 │        │       │       │
#      90 │        │       │       │
#      91 │        │       │       │def unload_ipython_extension(ipython):
#      92 │        │       │       │    """Unload the tracking extension from IPython."""
#      93 │        │       │       │    ipython.events.unregister("pre_run_cell", pre_run_cell)
#      94 │        │       │       │    ipython.events.unregister("post_run_cell", post_run_cell)
#      95 │        │       │       │    # Restore a plain dict namespace
#      96 │        │       │       │    plain = dict(ipython.user_ns)
#      97 │        │       │       │    ipython.user_ns = plain
#      98 │        │       │       │    print("🛑 tracking_ns unloaded: namespace restored.")
#      99 │        │       │       │
#         │        │       │       │
# ╶───────┼────────┼───────┼───────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╴
#         │        │       │       │function summary for /Users/freund/other/DataFerret/data_ferret/kernel/tracking.py
#      39 │   14%  │    3% │       │TrackingDict.__getitem__
#         ╵        ╵       ╵       ╵
# </code></pre>
#
# </details></div>

# %%
print(dists[0])
# Out:
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'><b>Cell eumk</b></div>
# [0.0, 1.7689822342636117, 1.6756189460078488, 1.8784671674096558, 1.668538645781009, 1.7120530417435178, 1.809282716986616, 1.6560561413135868, 1.6695669707691223, 2.0338468992694936, 1.9277594216104206, 1.2246364314549139, 1.8648579012776132, 1.9703417428828627, 1.8642708185751986, 1.7729393708720984, 1.6901290430422804, 1.6603290041585765, 1.7273763195772351, 1.7359583725449508, 1.6902547770189555, 1.9155079019080838, 1.5327624192619245, 2.139735001884626, 1.7909455647011057, 1.904731708234015, 1.3507844970186595, 1.7008295554359052, 1.7857806214857344, 1.7445592349233054, 1.848270555480945, 1.8989655713766944, 
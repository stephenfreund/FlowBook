# %%
import math
import random
import time
import numpy as np
# Out:
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'><b>Cell 6268e917-94eb-4f4f-9f09-3c988ae84e96</b></div>
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'>⏱️ 0.11s</div>

# %%
N, d = 2000, 20
pts = np.random.random((N, d))
# Out:
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'><b>Cell 36fbdc71-372c-4286-bd79-ff3409d131e7</b></div>
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'>⏱️ 0.09s</div>

# %%
def pairwise_distances(points):
    """
    Given points as a list of tuples (x1,…,xd),
    return an N×N matrix of Euclidean distances.
    """
    N = len(points)
    # initialize an N×N list of zeros
    D = [[0.0]*N for _ in range(N)]
    for i in range(N):
        for j in range(i+1, N):
            # compute distance
            s = 0.0
            for xi, xj in zip(points[i], points[j]):
                diff = xi - xj
                s += diff*diff
            dist = math.sqrt(s)
            D[i][j] = dist
            D[j][i] = dist
    return D
# Out:
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'><b>Cell c3e6c37c-ba02-484f-be6f-b421fe9922f5</b></div>
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'>⏱️ 0.09s</div>

# %%
_start = time.time()
dists = pairwise_distances(pts)
_end = time.time()
_diff = _end - _start
print("Time = ", _diff, "sec")
# Out:
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'><b>Cell 5bc00a9f-88b4-4caf-a325-0c5d76ea15ad</b></div>
# Time =  6.4069390296936035 sec
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'><details style='display: inline-block; text-align: left;'><summary>🔍 6.53s</summary>
#
# <pre style='margin: 0;'><code></code></pre>
#
# </details></div>

# %%
z = pairwise_distances(pts)
# Out:
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'><b>Cell 56133b90-d446-4778-8f14-b550e2d96677</b></div>
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'><details style='display: inline-block; text-align: left;'><summary>🔍 6.60s</summary>
#
# <pre style='margin: 0;'><code></code></pre>
#
# </details></div>

# %%
# def
def beep():
    return 11
# Out:
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'><b>Cell 0c7f59ae-0e2b-4ea7-859f-95864cfac2e5</b></div>
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'>⏱️ 0.13s</div>

# %%
beep()
# Out:
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'><b>Cell 78a4a230-f19a-497c-bbc0-72e30ffdc356</b></div>
# 11
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'>⏱️ 0.08s</div>

# %%
beep()
# Out:
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'><b>Cell 672d2942-b96d-4e26-b9a7-c79a09a16aa2</b></div>
# 13
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'>⏱️ 0.08s</div>

# %%
beep()
# Out:
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'><b>Cell 2fd348ec-25f9-4ef3-bb5f-c685f8fff1ff</b></div>
# 13
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'>⏱️ 0.12s</div>

# %%
beep()
# Out:
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'><b>Cell e371fb21-61e9-4b84-a5cf-eeac220ce797</b></div>
# 13
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'>⏱️ 0.08s</div>

# %%
beep()
# Out:
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'><b>Cell 34610c79-c5e1-4166-bae5-a55c5f5676e7</b></div>
# 13
# <div style='padding-left: 3em; font-size: 0.8em; background-color: #f0f0f8; margin-bottom: 0em;'>⏱️ 0.11s</div>

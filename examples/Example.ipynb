# %%
# %tracking on
# Out:
# UsageError: Line magic function `%tracking` not found.

# %%
# %scalene on
# Out:
# UsageError: Line magic function `%scalene` not found.

# %%
import math
import random
import time
import numpy as np
# Out:
# ✓ Run: 1 ms | State: 2 ms | Check: 3 ms

# %%
N, d = 2000, 20
pts = np.random.random((N, d))
# Out:
# ✓ Run: 2 ms | State: 3 ms | Check: 3 ms | Writes: N,d,pts

# %%
def pairwise_distances(points):
    """
    Given points as a list of tuples (x1,…,xd),
    return an N×N matrix of Euclidean distances.
    """
    N = len(points)
    # initialize an N×N list of zeros
    D = [[0.0]*N for _ in range(N)]
    for i in range(N):
        for j in range(i+1, N):
            # compute distance
            s = 0.0
            for xi, xj in zip(points[i], points[j]):
                diff = xi - xj
                s += diff*diff
            dist = math.sqrt(s)
            D[i][j] = dist
            D[j][i] = dist
    return D
# Out:
# ✓ Run: 2 ms | State: 4 ms | Check: 5 ms | Writes: pairwise_distances

# %%
_start = time.time()
dists = pairwise_distances(pts)
_end = time.time()
_diff = _end - _start
print("Time = ", _diff, "sec")
# Out:
# Time =  10.243499994277954 sec
# ✓ Run: 10245 ms | State: 453 ms | Check: 4 ms | Reads: pairwise_distances,pts | Writes: dists

# %%
print(dists[0])
# Out:
# [0.0, 1.8373475056404085, 1.8661013783802525, 1.852365610796702, 2.212334169531452, 1.4628665964567142, 1.9860576594360886, 2.0306197897048857, 2.21958510669479, 1.7798653330820493, 2.047136487994267, 1.3629210026259144, 1.8389320443518813, 2.0504577527926466, 1.8415265973439563, 2.0562636364925257, 1.8448580116443116, 1.843804494082807, 1.8732752090132723, 1.9387592928026787, 1.8459299761503285, 1.8365619012814343, 1.8472271802221354, 2.084451709453402, 1.6614052823394403, 1.823967310450376, 2.302406686466509, 1.683924229225105, 1.8435909516088849, 1.6363302781966995, 2.023543577899327, 1.7040942338752787, 2.004076716553917, 2.309994301665477, 1.8676305123996146, 1.9767031149398704, 2.175918185972228, 1.877009402114496, 1.8382779747404605, 2.0676603273493996, 1.6830287881232133, 1.6241897645056844, 1.9232909835696135, 2.116855174313707, 2.108647453367185, 1.9720154150904383, 1.9832206662610352, 1.9392367312516843, 1.8316002788141899, 1.8287836067207834, 2.4270328916080297, 2.067371783992278, 1.4016867378471145, 1.801967686946617, 2.092394357582541, 1.659864732813798, 1.677183667618358, 2.310944161970762, 2.1024355721082038, 1.5813461732788305, 2.126258127611158, 1.6741242016328595, 1.8654546545378667, 1.5894409627483066, 1.6618501016807419, 1.8136099132210286, 1.9736636993346544, 1.996164685472022, 1.7403207592050016, 2.0182849036721286